# %% [markdown]
# # Importando librerias

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sbn
import json
import os
from kaggle.api.kaggle_api_extended import KaggleApi
import zipfile
pd.options.display.max_columns = None

# %% [markdown]
# # Importando datos

# %%
with open('./kaggle.json') as file:
    credentialsKaggle = json.load(file)

os.environ['KAGGLE_USERNAME'] = credentialsKaggle['username']
os.environ['KAGGLE_KEY'] = credentialsKaggle['key']

# %%
# Descarga de la información
api = KaggleApi()
api.authenticate()

# Download the competition files
competition_name = 'playground-series-s4e6'
download_path = 'data/'
api.competition_download_files(competition_name, path=download_path)

# Unzip the downloaded files
for item in os.listdir(download_path):
    if item.endswith('.zip'):
        zip_ref = zipfile.ZipFile(os.path.join(download_path, item), 'r')
        zip_ref.extractall(download_path)
        zip_ref.close()
        print(f"Unzipped {item}")
# Out:
# Unzipped playground-series-s4e6.zip

# %%
dfTrain = pd.read_csv('data/train.csv')
dfTrain
# Out:
#           id  Marital status  Application mode  Application order  Course  \
# 0          0               1                 1                  1    9238
# 1          1               1                17                  1    9238
# 2          2               1                17                  2    9254
# 3          3               1                 1                  3    9500
# 4          4               1                 1                  2    9500
# ...      ...             ...               ...                ...     ...
# 76513  76513               1                17                  1    9254
# 76514  76514               1                 1                  6    9254
# 76515  76515               5                17                  1    9085
# 76516  76516               1                 1                  3    9070
# 76517  76517               1                 1                  1    9773
#
#        Daytime/evening attendance  Previous qualification  \
# ...

# %%
dfTrain.isnull().sum()
# Out:
# id                                                0
# Marital status                                    0
# Application mode                                  0
# Application order                                 0
# Course                                            0
# Daytime/evening attendance                        0
# Previous qualification                            0
# Previous qualification (grade)                    0
# Nacionality                                       0
# Mother's qualification                            0
# Father's qualification                            0
# Mother's occupation                               0
# Father's occupation                               0
# Admission grade                                   0
# Displaced                                         0
# Educational special needs                         0
# Debtor                                            0
# Tuition fees up to date                           0
# ...

# %%
dfTrain.describe(include='all').T
# Out:
#                                                   count unique       top  \
# id                                              76518.0    NaN       NaN
# Marital status                                  76518.0    NaN       NaN
# Application mode                                76518.0    NaN       NaN
# Application order                               76518.0    NaN       NaN
# Course                                          76518.0    NaN       NaN
# Daytime/evening attendance                      76518.0    NaN       NaN
# Previous qualification                          76518.0    NaN       NaN
# Previous qualification (grade)                  76518.0    NaN       NaN
# Nacionality                                     76518.0    NaN       NaN
# Mother's qualification                          76518.0    NaN       NaN
# Father's qualification                          76518.0    NaN       NaN
# Mother's occupation                             76518.0    NaN       NaN
# ...

# %%
col_numericas = [
    'Previous qualification (grade)',
    'Admission grade','Age at enrollment', 
    'Curricular units 1st sem (credited)',
    'Curricular units 1st sem (enrolled)',  
    'Curricular units 1st sem (evaluations)', 
    'Curricular units 1st sem (approved)', 
    'Curricular units 1st sem (grade)', 
    'Curricular units 1st sem (without evaluations)',
    'Curricular units 2nd sem (credited)',
    'Curricular units 2nd sem (enrolled)',  
    'Curricular units 2nd sem (evaluations)', 
    'Curricular units 2nd sem (approved)', 
    'Curricular units 2nd sem (grade)', 
    'Curricular units 2nd sem (without evaluations)',
    'Unemployment rate',
    'Inflation rate',
    'GDP'
]

col_categoricas = [
    'Marital status',
    'Application mode',
    'Course',
    'Previous qualification',
    'Nacionality',
    'Mother\'s qualification', 
    'Father\'s qualification',
    'Mother\'s occupation', 
    'Father\'s occupation',
    ]

col_ordinales = ['Application order']

col_dummies = [
    'Daytime/evening attendance',
    'Displaced', 
    'Educational special needs', 
    'Debtor', 
    'Tuition fees up to date', 
    'Gender', 
    'Scholarship holder', 
    'International'
    ]

col_target = 'Target'

# %%
display(dfTrain[col_target].value_counts(normalize=True).reset_index())
# Out:
#      Target  proportion
# 0  Graduate    0.474163
# 1   Dropout    0.330589
# 2  Enrolled    0.195248

# %%
for col in col_categoricas:
    print("--"*50)
    print(f"Variable: {col}")
    print("Distribucion")
    display(dfTrain[col].value_counts(normalize=True).reset_index())
    print("Distribucion target")
    display(pd.crosstab(index = dfTrain[col],columns = dfTrain[col_target], normalize='index'))
# Out:
# ----------------------------------------------------------------------------------------------------
# Variable: Marital status
# Distribucion
#    Marital status  proportion
# 0               1    0.917287
# 1               2    0.069212
# 2               4    0.011318
# 3               5    0.001516
# 4               6    0.000457
# 5               3    0.000209
# Distribucion target
# Target           Dropout  Enrolled  Graduate
# Marital status
# 1               0.309536  0.199974  0.490490
# 2               0.560423  0.138784  0.300793
# 3               0.437500  0.125000  0.437500
# 4               0.587760  0.169746  0.242494
# 5               0.543103  0.112069  0.344828
# 6               0.657143  0.200000  0.142857
# ----------------------------------------------------------------------------------------------------
# Variable: Application mode
# Distribucion
#     Application mode  proportion
# 0                  1    0.460375
# 1                 17    0.215936
# ...

# %%
for col in col_dummies:
    print("--"*50)
    print(f"Variable: {col}")
    print("Distribucion")
    display(dfTrain[col].value_counts(normalize=True).reset_index())
    print("Distribucion target")
    display(pd.crosstab(index = dfTrain[col],columns = dfTrain[col_target], normalize='index'))
# Out:
# ----------------------------------------------------------------------------------------------------
# Variable: Daytime/evening attendance
# Distribucion
#    Daytime/evening attendance  proportion
# 0                           1    0.915314
# 1                           0    0.084686
# Distribucion target
# Target                       Dropout  Enrolled  Graduate
# Daytime/evening attendance
# 0                           0.531327  0.156173   0.31250
# 1                           0.312016  0.198863   0.48912
# ----------------------------------------------------------------------------------------------------
# Variable: Displaced
# Distribucion
#    Displaced  proportion
# 0          1    0.569265
# 1          0    0.430735
# Distribucion target
# Target      Dropout  Enrolled  Graduate
# Displaced
# 0          0.407506  0.194181  0.398313
# 1          0.272389  0.196056  0.531555
# ...

# %%
for col in col_ordinales:
    print("--"*50)
    print(f"Variable: {col}")
    print("Distribucion")
    display(dfTrain[col].value_counts(normalize=True).reset_index().sort_values(by = col, ascending=True))
    print("Distribucion target")
    display(pd.crosstab(index = dfTrain[col],columns = dfTrain[col_target], normalize='index'))
# Out:
# ----------------------------------------------------------------------------------------------------
# Variable: Application order
# Distribucion
#    Application order  proportion
# 6                  0    0.000039
# 0                  1    0.710696
# 1                  2    0.115986
# 2                  3    0.070101
# 3                  4    0.049949
# 4                  5    0.027771
# 5                  6    0.025445
# 7                  9    0.000013
# Distribucion target
# Target              Dropout  Enrolled  Graduate
# Application order
# 0                  0.666667  0.000000  0.333333
# 1                  0.364631  0.206009  0.429360
# 2                  0.267268  0.194479  0.538254
# 3                  0.212901  0.171327  0.615772
# 4                  0.226321  0.122972  0.650706
# 5                  0.359529  0.181176  0.459294
# 6                  0.165383  0.121212  0.713405
# 9                  0.000000  1.000000  0.000000

# %%
for col in col_numericas:
    print("--"*50)
    print(f"Variable: {col}")
    plt.figure(figsize=(10,5))
    sbn.histplot(dfTrain[col], kde=True,bins=100)

    plt.figure(figsize=(10,5))
    sbn.boxplot(x=col,y=col_target,data=dfTrain)
    plt.show()
# Out:
# ----------------------------------------------------------------------------------------------------
# Variable: Previous qualification (grade)
# ----------------------------------------------------------------------------------------------------
# Variable: Admission grade
# ----------------------------------------------------------------------------------------------------
# Variable: Age at enrollment
# ----------------------------------------------------------------------------------------------------
# Variable: Curricular units 1st sem (credited)
# ----------------------------------------------------------------------------------------------------
# Variable: Curricular units 1st sem (enrolled)
# ----------------------------------------------------------------------------------------------------
# Variable: Curricular units 1st sem (evaluations)
# ----------------------------------------------------------------------------------------------------
# ...
